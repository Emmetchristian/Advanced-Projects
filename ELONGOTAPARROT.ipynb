# %% [markdown]
# <a href="https://colab.research.google.com/github/Emmetchristian/Advanced-Projects/blob/main/ELONGOTAPARROT.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ![download (1).jpeg](data:image/jpeg;base64,...)
#
# 1. UPLOAD TweetsElonMusk.csv INTO FILES
# 2. RUN EVERYTHING EXCEPT THE FIRST ONE
# 3. RUN THE FIRST ONE
# 4. CODE CANNOT HANDLE PUTTING IN WORDS IN PLACES WHERE INTS ARE REQUIRED
# 5. CODE CANNOT HANDLE INPUTING A WORD THAT IS NOT IN THE DATABASE
#
# so dont enter "Trichotillomania" for exmple because Elon prolly hasent said that
#
# if your wondering what that is.. it is the urge to pull your hair out which is what this project made me want to do

# %%
# Generate list of sentences with similar contextual meaning
import urllib.request
from PIL import Image
from bs4 import BeautifulSoup
import requests

elon = open('TweetsElonMusk.csv', encoding='utf8').read()
corpus = elon.split()


def make_trios(corpus):
    for i in range(len(corpus) - 2):
        yield corpus[i], corpus[i + 1], corpus[i + 2]

pairs = make_trios(corpus)

word_dict = {}

for word_1, word_2, word_3 in pairs:
    if word_1 in word_dict.keys():
        word_dict[word_1].append(word_2)
        if word_2 in word_dict.keys():
            word_dict[word_2].append(word_3)
    else:
        word_dict[word_2] = [word_3]
        word_dict[word_1] = [word_2]


first_word = input("Give me a word and I will finish the tweet with what Elon would say: ")
chain = [first_word]
n_words = input("How many words should the tweet be: ")

for i in range(int(n_words)):
    chain.append(np.random.choice(word_dict[chain[-1]]))

phrase = [' '.join(chain)]

print("-"*100)
print("Input_phrase: ", ' '.join(phrase))
print("-"*100)

text = ' '.join(phrase)

#printing response

print("-"*100)
print("Corrected_phrase: ", get_response(text, 5))
print("-"*100)

def get_soup(url,header):
  return BeautifulSoup(urllib2.urlopen(urllib2.Request(url,headers=header)))

image_type = "Action"
query = get_response(text, 5) [4]
query= query.split()
query='+'.join(query)
url="https://www.google.com/search?q="+ query + "&safe=active&rlz=1C5GCEM_enUS1040US1040&source=lnms&tbm=isch&sa=X&ved=2ahUKEwiRkvfEr_f8AhXdQzABHZKHAcgQ_AUoAXoECAEQAw&biw=1254&bih=699&dpr=2"
 
print(url)
# Out:
# Give me a word and I will finish the tweet with what Elon would say: like
# How many words should the tweet be: 6
# ----------------------------------------------------------------------------------------------------
# Input_phrase:  like to solve brain/spine injuries deaths r
# ----------------------------------------------------------------------------------------------------
# ----------------------------------------------------------------------------------------------------
# Corrected_phrase:  ['It would be great to solve brain/spine injuries deaths.', 'It would be nice to solve brain/spine injuries deaths.', "It's like to solve brain/spine injuries deaths.", 'I would like to solve brain/spine injuries deaths.', 'I like to solve brain/spine injuries deaths.']
# ----------------------------------------------------------------------------------------------------
# ...

# %%
#importing the PEGASUS Transformer model
import torch
from transformers import PegasusForConditionalGeneration, PegasusTokenizer
 
model_name = 'tuner007/pegasus_paraphrase'
torch_device = 'cuda' if torch.cuda.is_available() else 'cpu'
tokenizer = PegasusTokenizer.from_pretrained(model_name)
model = PegasusForConditionalGeneration.from_pretrained(model_name).to(torch_device)
 
#setting up the model
def get_response(input_text,num_return_sequences):
  batch = tokenizer.prepare_seq2seq_batch([input_text],truncation=True,padding='longest',max_length=60, return_tensors="pt").to(torch_device)
  translated = model.generate(**batch,max_length=60,num_beams=10, num_return_sequences=num_return_sequences, temperature=1.5)
  tgt_text = tokenizer.batch_decode(translated, skip_special_tokens=True)
  return tgt_text

# %%
from bs4 import BeautifulSoup
import requests
import re
from urllib.request import urlopen
import os
import numpy as np

# %%
# !pip install sentence-splitter
# !pip install transformers
# !pip install SentencePiece
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 45.0/45.0 KB 3.0 MB/s eta 0:00:00
# ...
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 6.3/6.3 MB 47.3 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 7.6/7.6 MB 62.4 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 190.3/190.3 KB 19.8 MB/s eta 0:00:00
# ...
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.3/1.3 MB 17.7 MB/s eta 0:00:00
# ...

# %%
pip install anvil-uplink

# %%
import anvil.server

anvil.server.connect("server_MHSICEGBXHOVZGUQVKYWTULJ-RSC5VCGFVXVOWRMT")
